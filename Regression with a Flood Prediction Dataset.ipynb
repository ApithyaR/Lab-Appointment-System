# %% [markdown]
# <a href="https://colab.research.google.com/github/ApithyaR/Lab-Appointment-System/blob/main/Regression%20with%20a%20Flood%20Prediction%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv(r"/content/train.csv")

# %%
df.shape
# Out:
# (140892, 22)

# %%
df.describe()
# Out:
#                   id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  140892.000000     140892.000000       140892.000000    140892.000000
# mean    70445.500000          4.922771            4.935121         4.958337
# std     40672.161401          2.058865            2.100184         2.073145
# min         0.000000          0.000000            0.000000         0.000000
# 25%     35222.750000          3.000000            3.000000         4.000000
# 50%     70445.500000          5.000000            5.000000         5.000000
# 75%    105668.250000          6.000000            6.000000         6.000000
# max    140891.000000         16.000000           17.000000        16.000000
#
#        Deforestation   Urbanization  ClimateChange    DamsQuality  \
# count  140892.000000  140892.000000  140892.000000  140892.000000
# mean        4.942651       4.941863       4.928576       4.949259
# std         2.046490       2.081913       2.059971       2.087346
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140892 entries, 0 to 140891
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               140892 non-null  int64
#  1   MonsoonIntensity                 140892 non-null  int64
#  2   TopographyDrainage               140892 non-null  int64
#  3   RiverManagement                  140892 non-null  int64
#  4   Deforestation                    140892 non-null  int64
#  5   Urbanization                     140892 non-null  int64
#  6   ClimateChange                    140892 non-null  int64
#  7   DamsQuality                      140892 non-null  int64
#  8   Siltation                        140892 non-null  int64
#  9   AgriculturalPractices            140892 non-null  int64
#  10  Encroachments                    140892 non-null  int64
#  11  IneffectiveDisasterPreparedness  140892 non-null  int64
# ...

# %%
df.isnull()
# Out:
#            id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0       False             False               False            False
# 1       False             False               False            False
# 2       False             False               False            False
# 3       False             False               False            False
# 4       False             False               False            False
# ...       ...               ...                 ...              ...
# 140887  False             False               False            False
# 140888  False             False               False            False
# 140889  False             False               False            False
# 140890  False             False               False            False
# 140891  False             False               False            False
#
#         Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# ...

# %%
df.isnull().value_counts()
# Out:
# id     MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  Encroachments  IneffectiveDisasterPreparedness  DrainageSystems  CoastalVulnerability  Landslides  Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  InadequatePlanning  PoliticalFactors  FloodProbability
# False  False             False               False            False          False         False          False        False      False                  False          False                            False            False                 False       False       False                        False            False        False               False             False               140891
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 1
# PoliticalFactors                   1
# FloodProbability                   1
# dtype: int64

# %%
# Impute missing values with the mean of the column
df['InadequatePlanning'].fillna(df['InadequatePlanning'].mean(), inplace=True)
df['PoliticalFactors'].fillna(df['PoliticalFactors'].mean(), inplace=True)
df['FloodProbability'].fillna(df['FloodProbability'].mean(), inplace=True)

# %%
# Verify that there are no missing values left
print(df.isnull().sum())
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64
